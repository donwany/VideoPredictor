# %%
# !git clone https://github.com/donwany/VideoPredictor
# Out:
# Cloning into 'VideoPredictor'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 24 (delta 7), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (24/24), done.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/jurjsorinliviu/Sports-Type-Classifier.git
# Out:
# Cloning into 'Sports-Type-Classifier'...
# remote: Enumerating objects: 14521, done.
# remote: Total 14521 (delta 0), reused 0 (delta 0), pack-reused 14521
# Receiving objects: 100% (14521/14521), 592.88 MiB | 11.99 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# Checking out files: 100% (14619/14619), done.

# %%
# %cd /content/Sports-Type-Classifier
# %ls /content/Sports-Type-Classifier/data | grep -Ev "urls|models|csv|pkl"
# Out:
# /content/Sports-Type-Classifier
# badminton/
# baseball/
# basketball/
# boxing/
# chess/
# cricket/
# fencing/
# football/
# formula1/
# gymnastics/
# hockey/
# ice_hockey/
# kabaddi/
# motogp/
# shooting/
# swimming/
# table_tennis/
# tennis/
# volleyball/
# weight_lifting/
# wrestling/
# wwe/

# %% [markdown]
# ## ResNet

# %%
# !python /content/VideoPredictor/train.py \
   --dataset /content/Sports-Type-Classifier/data \
   --model /content/model/activity.model \
   --label-bin /content/model/lb.pickle \
   --epochs 50
# Out:
# [INFO] loading images...
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: extra compressed data
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: extra compressed data
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# 2022-05-06 05:02:05.152709: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# ...
# 234708992/234698864 [==============================] - 8s 0us/step
# [INFO] compiling model...
# [INFO] training head...
# ...

# %% [markdown]
# ## VGG-16

# %%
# !python /content/VideoPredictor/train.py \
   --dataset /content/Sports-Type-Classifier/data \
   --model model-vgg16/activity.model \
   --label-bin model-vgg16/lb.pickle \
   --epochs 50
# Out:
# [INFO] loading images...
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: extra compressed data
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: extra compressed data
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# 2022-05-06 06:16:01.834384: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# ...
# 58900480/58889256 [==============================] - 1s 0us/step
# [INFO] compiling model...
# [INFO] training head...
# ...

# %% [markdown]
# ## DenseNet201

# %%
# !python /content/VideoPredictor/train.py \
   --dataset /content/Sports-Type-Classifier/data \
   --model model-densenet/activity.model \
   --label-bin model-densenet/lb.pickle \
   --epochs 50
# Out:
# [INFO] loading images...
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: extra compressed data
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: extra compressed data
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# 2022-05-06 06:55:19.268221: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# ...
# 74850304/74836368 [==============================] - 3s 0us/step
# [INFO] compiling model...
# [INFO] training head...
# ...

# %% [markdown]
# ## InceptionV3

# %%
# !python /content/VideoPredictor/train.py \
   --dataset /content/Sports-Type-Classifier/data \
   --model model-inception/activity.model \
   --label-bin model-inception/lb.pickle \
   --epochs 50
# Out:
# [INFO] loading images...
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: extra compressed data
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: extra compressed data
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# 2022-05-06 07:26:14.027624: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# [INFO] compiling model...
# [INFO] training head...
# ...

# %% [markdown]
# ##Predictions

# %%
# !python /content/VideoPredictor/predict_video.py \
    --model /content/Sports-Type-Classifier/model-resnet/activity.model \
    --label-bin /content/Sports-Type-Classifier/model-resnet/lb.pickle \
    --input clips/tennis.mp4 \
    --output output/tennis_128frames_smoothened.avi \
    --size 128
